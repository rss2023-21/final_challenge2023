# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
all_updates = np.load('all_updates.npy')
all_updates_sample = all_updates[::10, :]
t = np.arange(all_updates_sample.shape[0])

# %%
plt.figure()
plt.plot(t, all_updates_sample[:, 0], label='dist_error')
plt.plot(t, all_updates_sample[:, 1], label='angle_error')
plt.legend()
